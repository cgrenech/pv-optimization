# %% [markdown]
# # Generate steady and transient flamelet for $NH_3$/$H_2$-air
#
# ***

# %%
import numpy as np
import matplotlib.pyplot as plt
from spitfire.chemistry import flamelet
from spitfire.chemistry import tabulation
from spitfire.chemistry import analysis
from spitfire import Flamelet, FlameletSpec
from spitfire.chemistry.mechanism import ChemicalMechanismSpec
from cantera import gas_constant
from PCAfold import preprocess
from PCAfold import reduction
import cantera as ct

# %matplotlib inline

# %%
ct.__version__
# Out:
# '3.2.0'

# %% [markdown]
# **Save data sets to `.csv`?**

# %%
save_csv = True

# %% [markdown]
# **Specify `filename_prefix` that will be added to the saved `.csv` files:**

# %%
filename_prefix = 'SLF-NH3-H2-air-25perc'

# %% [markdown]
# **Generate transient part?**

# %%
generate_transient = False

# %% [markdown]
# **Remove $N_2$ species when saving the data set?**

# %%
remove_N2 = False

# %% [markdown]
# #### Specify chemical mechanism:

# %%
chemical_mechanism = ChemicalMechanismSpec('ammonia-1atm.yaml', 'gas')

# %%
species_names = chemical_mechanism.species_names
print(species_names)
# Out:
# ['AR', 'N2', 'HE', 'H2', 'H', 'O2', 'O', 'H2O', 'OH', 'H2O2', 'HO2', 'NO', 'N2O', 'NO2', 'HNO', 'HNO2', 'HONO', 'HONO2', 'N2H2', 'H2NN', 'NH2OH', 'HNOH', 'NH3', 'N2H4', 'N', 'NO3', 'NH', 'NNH', 'NH2', 'H2NO', 'N2H3']

# %% [markdown]
# #### Specify fuel and air streams:

# %%
pressure = 101325.

# Fuel and air streams:
fuel = chemical_mechanism.stream('X', 'NH3:3 H2:1')
fuel.TP = 300., pressure
air = chemical_mechanism.stream(stp_air=True)
air.TP = 300., pressure

# Print information about stoichiometric mixture fraction:
Z_stoich = chemical_mechanism.stoich_mixture_fraction(fuel, air)
print('Stoichiometric mixture fraction:')
print(Z_stoich)
# Out:
# Stoichiometric mixture fraction:
# 0.12373159044403234

# %% [markdown]
# ***
#
# ## Generate steady flamelet library:

# %%
# dissipation_rates = np.logspace(-2, 1.56, 200)

# %%
dissipation_rates = np.vstack((np.logspace(-2, 0.68, 100)[:,None], np.linspace(5.05,20.2,70)[:,None], np.logspace(1.31,1.56,60)[:,None])).ravel()

# %%
flamelet_specs = {'mech_spec': chemical_mechanism,
                  'oxy_stream': air,
                  'fuel_stream': fuel,
                  'grid_points': 200,
                  'grid_cluster_intensity': 3,
                  'grid_type': 'clustered',
                  'include_enthalpy_flux': False,
                  'include_variable_cp': False}

l_steady = tabulation.build_adiabatic_slfm_library(flamelet_specs,
                                    diss_rate_values=dissipation_rates,
                                    diss_rate_ref='stoichiometric',
                                    verbose=True)
# Out:
# ----------------------------------------------------------------------------------
# building adiabatic SLFM library
# ----------------------------------------------------------------------------------
# - mechanism: ammonia-1atm.yaml
# - 31 species, 203 reactions
# - stoichiometric mixture fraction: 0.124
# ----------------------------------------------------------------------------------
#    1/ 230 (chi_stoich =  1.0e-02 1/s)  converged in   1.33 s, T_max = 2009.1
#    2/ 230 (chi_stoich =  1.1e-02 1/s)  converged in   0.02 s, T_max = 2008.5
#    3/ 230 (chi_stoich =  1.1e-02 1/s)  converged in   0.02 s, T_max = 2007.9
#    4/ 230 (chi_stoich =  1.2e-02 1/s)  converged in   0.01 s, T_max = 2007.2
#    5/ 230 (chi_stoich =  1.3e-02 1/s)  converged in   0.02 s, T_max = 2006.6
#    6/ 230 (chi_stoich =  1.4e-02 1/s)  converged in   0.02 s, T_max = 2005.9
#    7/ 230 (chi_stoich =  1.5e-02 1/s)  converged in   0.02 s, T_max = 2005.3
#    8/ 230 (chi_stoich =  1.5e-02 1/s)  converged in   0.01 s, T_max = 2004.7
#    9/ 230 (chi_stoich =  1.6e-02 1/s)  converged in   0.02 s, T_max = 2004.0
#   10/ 230 (chi_stoich =  1.8e-02 1/s)  converged in   0.02 s, T_max = 2003.4
#   11/ 230 (chi_stoich =  1.9e-02 1/s)  converged in   0.02 s, T_max = 2003.1
#   12/ 230 (chi_stoich =  2.0e-02 1/s)  converged in   0.02 s, T_max = 2002.7
#   13/ 230 (chi_stoich =  2.1e-02 1/s)  converged in   0.02 s, T_max = 2002.4
#   14/ 230 (chi_stoich =  2.2e-02 1/s)  converged in   0.02 s, T_max = 2002.0
#   15/ 230 (chi_stoich =  2.4e-02 1/s)  converged in   0.02 s, T_max = 2001.7
#   16/ 230 (chi_stoich =  2.5e-02 1/s)  converged in   0.02 s, T_max = 2001.3
#   17/ 230 (chi_stoich =  2.7e-02 1/s)  converged in   0.02 s, T_max = 2001.0
#   18/ 230 (chi_stoich =  2.9e-02 1/s)  converged in   0.02 s, T_max = 2000.7
#   19/ 230 (chi_stoich =  3.1e-02 1/s)  converged in   0.02 s, T_max = 2000.3
#   20/ 230 (chi_stoich =  3.3e-02 1/s)  converged in   0.02 s, T_max = 2000.0
#   21/ 230 (chi_stoich =  3.5e-02 1/s)  converged in   0.02 s, T_max = 1999.6
#   22/ 230 (chi_stoich =  3.7e-02 1/s)  converged in   0.02 s, T_max = 1999.2
#   23/ 230 (chi_stoich =  3.9e-02 1/s)  converged in   0.02 s, T_max = 1998.9
#   24/ 230 (chi_stoich =  4.2e-02 1/s)  converged in   0.02 s, T_max = 1998.5
#   25/ 230 (chi_stoich =  4.5e-02 1/s)  converged in   0.02 s, T_max = 1998.1
#   26/ 230 (chi_stoich =  4.8e-02 1/s)  converged in   0.02 s, T_max = 1997.7
#   27/ 230 (chi_stoich =  5.1e-02 1/s)  converged in   0.02 s, T_max = 1997.3
#   28/ 230 (chi_stoich =  5.4e-02 1/s)  converged in   0.02 s, T_max = 1996.9
#   29/ 230 (chi_stoich =  5.7e-02 1/s)  converged in   0.02 s, T_max = 1996.5
#   30/ 230 (chi_stoich =  6.1e-02 1/s)  converged in   0.02 s, T_max = 1996.1
#   31/ 230 (chi_stoich =  6.5e-02 1/s)  converged in   0.02 s, T_max = 1995.7
#   32/ 230 (chi_stoich =  6.9e-02 1/s)  converged in   0.02 s, T_max = 1995.3
#   33/ 230 (chi_stoich =  7.3e-02 1/s)  converged in   0.02 s, T_max = 1994.8
#   34/ 230 (chi_stoich =  7.8e-02 1/s)  converged in   0.02 s, T_max = 1994.4
#   35/ 230 (chi_stoich =  8.3e-02 1/s)  converged in   0.02 s, T_max = 1993.9
#   36/ 230 (chi_stoich =  8.9e-02 1/s)  converged in   0.02 s, T_max = 1993.4
#   37/ 230 (chi_stoich =  9.4e-02 1/s)  converged in   0.02 s, T_max = 1992.9
#   38/ 230 (chi_stoich =  1.0e-01 1/s)  converged in   0.02 s, T_max = 1992.4
#   39/ 230 (chi_stoich =  1.1e-01 1/s)  converged in   0.02 s, T_max = 1991.9
#   40/ 230 (chi_stoich =  1.1e-01 1/s)  converged in   0.02 s, T_max = 1991.4
#   41/ 230 (chi_stoich =  1.2e-01 1/s)  converged in   0.02 s, T_max = 1990.8
#   42/ 230 (chi_stoich =  1.3e-01 1/s)  converged in   0.02 s, T_max = 1990.2
#   43/ 230 (chi_stoich =  1.4e-01 1/s)  converged in   0.02 s, T_max = 1989.7
#   44/ 230 (chi_stoich =  1.5e-01 1/s)  converged in   0.02 s, T_max = 1989.1
#   45/ 230 (chi_stoich =  1.6e-01 1/s)  converged in   0.02 s, T_max = 1988.5
#   46/ 230 (chi_stoich =  1.7e-01 1/s)  converged in   0.02 s, T_max = 1987.9
#   47/ 230 (chi_stoich =  1.8e-01 1/s)  converged in   0.02 s, T_max = 1987.4
#   48/ 230 (chi_stoich =  1.9e-01 1/s)  converged in   0.02 s, T_max = 1986.8
#   49/ 230 (chi_stoich =  2.0e-01 1/s)  converged in   0.02 s, T_max = 1986.2
#   50/ 230 (chi_stoich =  2.1e-01 1/s)  converged in   0.02 s, T_max = 1985.6
#   51/ 230 (chi_stoich =  2.3e-01 1/s)  converged in   0.02 s, T_max = 1985.0
#   52/ 230 (chi_stoich =  2.4e-01 1/s)  converged in   0.02 s, T_max = 1984.3
#   53/ 230 (chi_stoich =  2.6e-01 1/s)  converged in   0.02 s, T_max = 1983.7
#   54/ 230 (chi_stoich =  2.7e-01 1/s)  converged in   0.02 s, T_max = 1983.0
#   55/ 230 (chi_stoich =  2.9e-01 1/s)  converged in   0.02 s, T_max = 1982.2
#   56/ 230 (chi_stoich =  3.1e-01 1/s)  converged in   0.02 s, T_max = 1981.5
#   57/ 230 (chi_stoich =  3.3e-01 1/s)  converged in   0.02 s, T_max = 1980.7
#   58/ 230 (chi_stoich =  3.5e-01 1/s)  converged in   0.02 s, T_max = 1980.0
#   59/ 230 (chi_stoich =  3.7e-01 1/s)  converged in   0.02 s, T_max = 1979.1
#   60/ 230 (chi_stoich =  4.0e-01 1/s)  converged in   0.02 s, T_max = 1978.3
#   61/ 230 (chi_stoich =  4.2e-01 1/s)  converged in   0.02 s, T_max = 1977.4
#   62/ 230 (chi_stoich =  4.5e-01 1/s)  converged in   0.02 s, T_max = 1976.5
#   63/ 230 (chi_stoich =  4.8e-01 1/s)  converged in   0.02 s, T_max = 1975.6
#   64/ 230 (chi_stoich =  5.1e-01 1/s)  converged in   0.02 s, T_max = 1974.7
#   65/ 230 (chi_stoich =  5.4e-01 1/s)  converged in   0.02 s, T_max = 1973.7
#   66/ 230 (chi_stoich =  5.7e-01 1/s)  converged in   0.02 s, T_max = 1972.7
#   67/ 230 (chi_stoich =  6.1e-01 1/s)  converged in   0.02 s, T_max = 1971.6
#   68/ 230 (chi_stoich =  6.5e-01 1/s)  converged in   0.02 s, T_max = 1970.6
#   69/ 230 (chi_stoich =  6.9e-01 1/s)  converged in   0.02 s, T_max = 1969.5
#   70/ 230 (chi_stoich =  7.4e-01 1/s)  converged in   0.02 s, T_max = 1968.3
#   71/ 230 (chi_stoich =  7.9e-01 1/s)  converged in   0.02 s, T_max = 1967.3
#   72/ 230 (chi_stoich =  8.4e-01 1/s)  converged in   0.02 s, T_max = 1966.2
#   73/ 230 (chi_stoich =  8.9e-01 1/s)  converged in   0.02 s, T_max = 1965.0
#   74/ 230 (chi_stoich =  9.5e-01 1/s)  converged in   0.02 s, T_max = 1963.8
#   75/ 230 (chi_stoich =  1.0e+00 1/s)  converged in   0.02 s, T_max = 1962.6
#   76/ 230 (chi_stoich =  1.1e+00 1/s)  converged in   0.02 s, T_max = 1961.4
#   77/ 230 (chi_stoich =  1.1e+00 1/s)  converged in   0.02 s, T_max = 1960.1
#   78/ 230 (chi_stoich =  1.2e+00 1/s)  converged in   0.02 s, T_max = 1958.8
#   79/ 230 (chi_stoich =  1.3e+00 1/s)  converged in   0.02 s, T_max = 1957.4
#   80/ 230 (chi_stoich =  1.4e+00 1/s)  converged in   0.02 s, T_max = 1956.0
#   81/ 230 (chi_stoich =  1.5e+00 1/s)  converged in   0.02 s, T_max = 1954.5
#   82/ 230 (chi_stoich =  1.6e+00 1/s)  converged in   0.02 s, T_max = 1953.0
#   83/ 230 (chi_stoich =  1.7e+00 1/s)  converged in   0.02 s, T_max = 1951.5
#   84/ 230 (chi_stoich =  1.8e+00 1/s)  converged in   0.02 s, T_max = 1949.9
#   85/ 230 (chi_stoich =  1.9e+00 1/s)  converged in   0.02 s, T_max = 1948.3
#   86/ 230 (chi_stoich =  2.0e+00 1/s)  converged in   0.02 s, T_max = 1946.6
#   87/ 230 (chi_stoich =  2.1e+00 1/s)  converged in   0.02 s, T_max = 1944.8
#   88/ 230 (chi_stoich =  2.3e+00 1/s)  converged in   0.02 s, T_max = 1943.1
#   89/ 230 (chi_stoich =  2.4e+00 1/s)  converged in   0.02 s, T_max = 1941.3
#   90/ 230 (chi_stoich =  2.6e+00 1/s)  converged in   0.02 s, T_max = 1939.5
#   91/ 230 (chi_stoich =  2.7e+00 1/s)  converged in   0.02 s, T_max = 1937.6
#   92/ 230 (chi_stoich =  2.9e+00 1/s)  converged in   0.02 s, T_max = 1935.7
#   93/ 230 (chi_stoich =  3.1e+00 1/s)  converged in   0.02 s, T_max = 1933.6
#   94/ 230 (chi_stoich =  3.3e+00 1/s)  converged in   0.02 s, T_max = 1931.5
#   95/ 230 (chi_stoich =  3.5e+00 1/s)  converged in   0.02 s, T_max = 1929.4
#   96/ 230 (chi_stoich =  3.7e+00 1/s)  converged in   0.02 s, T_max = 1927.2
#   97/ 230 (chi_stoich =  4.0e+00 1/s)  converged in   0.02 s, T_max = 1924.9
#   98/ 230 (chi_stoich =  4.2e+00 1/s)  converged in   0.02 s, T_max = 1922.5
#   99/ 230 (chi_stoich =  4.5e+00 1/s)  converged in   0.02 s, T_max = 1920.0
#  100/ 230 (chi_stoich =  4.8e+00 1/s)  converged in   0.02 s, T_max = 1917.4
#  101/ 230 (chi_stoich =  5.0e+00 1/s)  converged in   0.02 s, T_max = 1915.2
#  102/ 230 (chi_stoich =  5.3e+00 1/s)  converged in   0.02 s, T_max = 1913.4
#  103/ 230 (chi_stoich =  5.5e+00 1/s)  converged in   0.02 s, T_max = 1911.6
#  104/ 230 (chi_stoich =  5.7e+00 1/s)  converged in   0.02 s, T_max = 1909.9
#  105/ 230 (chi_stoich =  5.9e+00 1/s)  converged in   0.02 s, T_max = 1908.2
#  106/ 230 (chi_stoich =  6.1e+00 1/s)  converged in   0.02 s, T_max = 1906.5
#  107/ 230 (chi_stoich =  6.4e+00 1/s)  converged in   0.02 s, T_max = 1904.8
#  108/ 230 (chi_stoich =  6.6e+00 1/s)  converged in   0.02 s, T_max = 1903.2
#  109/ 230 (chi_stoich =  6.8e+00 1/s)  converged in   0.02 s, T_max = 1901.5
#  110/ 230 (chi_stoich =  7.0e+00 1/s)  converged in   0.02 s, T_max = 1899.9
#  111/ 230 (chi_stoich =  7.2e+00 1/s)  converged in   0.02 s, T_max = 1898.3
#  112/ 230 (chi_stoich =  7.5e+00 1/s)  converged in   0.02 s, T_max = 1896.8
#  113/ 230 (chi_stoich =  7.7e+00 1/s)  converged in   0.02 s, T_max = 1895.2
#  114/ 230 (chi_stoich =  7.9e+00 1/s)  converged in   0.02 s, T_max = 1893.7
#  115/ 230 (chi_stoich =  8.1e+00 1/s)  converged in   0.02 s, T_max = 1892.2
#  116/ 230 (chi_stoich =  8.3e+00 1/s)  converged in   0.01 s, T_max = 1890.7
#  117/ 230 (chi_stoich =  8.6e+00 1/s)  converged in   0.02 s, T_max = 1889.2
#  118/ 230 (chi_stoich =  8.8e+00 1/s)  converged in   0.01 s, T_max = 1887.7
#  119/ 230 (chi_stoich =  9.0e+00 1/s)  converged in   0.01 s, T_max = 1886.3
#  120/ 230 (chi_stoich =  9.2e+00 1/s)  converged in   0.01 s, T_max = 1884.8
#  121/ 230 (chi_stoich =  9.4e+00 1/s)  converged in   0.02 s, T_max = 1883.4
#  122/ 230 (chi_stoich =  9.7e+00 1/s)  converged in   0.01 s, T_max = 1881.9
#  123/ 230 (chi_stoich =  9.9e+00 1/s)  converged in   0.02 s, T_max = 1880.5
#  124/ 230 (chi_stoich =  1.0e+01 1/s)  converged in   0.02 s, T_max = 1879.1
#  125/ 230 (chi_stoich =  1.0e+01 1/s)  converged in   0.02 s, T_max = 1877.7
#  126/ 230 (chi_stoich =  1.1e+01 1/s)  converged in   0.02 s, T_max = 1876.3
#  127/ 230 (chi_stoich =  1.1e+01 1/s)  converged in   0.02 s, T_max = 1875.0
#  128/ 230 (chi_stoich =  1.1e+01 1/s)  converged in   0.02 s, T_max = 1873.6
#  129/ 230 (chi_stoich =  1.1e+01 1/s)  converged in   0.02 s, T_max = 1872.3
#  130/ 230 (chi_stoich =  1.1e+01 1/s)  converged in   0.02 s, T_max = 1870.9
#  131/ 230 (chi_stoich =  1.2e+01 1/s)  converged in   0.01 s, T_max = 1869.6
#  132/ 230 (chi_stoich =  1.2e+01 1/s)  converged in   0.01 s, T_max = 1868.3
#  133/ 230 (chi_stoich =  1.2e+01 1/s)  converged in   0.02 s, T_max = 1866.9
#  134/ 230 (chi_stoich =  1.2e+01 1/s)  converged in   0.01 s, T_max = 1865.6
#  135/ 230 (chi_stoich =  1.3e+01 1/s)  converged in   0.01 s, T_max = 1864.3
#  136/ 230 (chi_stoich =  1.3e+01 1/s)  converged in   0.02 s, T_max = 1863.0
#  137/ 230 (chi_stoich =  1.3e+01 1/s)  converged in   0.02 s, T_max = 1861.7
#  138/ 230 (chi_stoich =  1.3e+01 1/s)  converged in   0.02 s, T_max = 1860.4
#  139/ 230 (chi_stoich =  1.3e+01 1/s)  converged in   0.02 s, T_max = 1859.1
#  140/ 230 (chi_stoich =  1.4e+01 1/s)  converged in   0.02 s, T_max = 1857.8
#  141/ 230 (chi_stoich =  1.4e+01 1/s)  converged in   0.01 s, T_max = 1856.5
#  142/ 230 (chi_stoich =  1.4e+01 1/s)  converged in   0.02 s, T_max = 1855.2
#  143/ 230 (chi_stoich =  1.4e+01 1/s)  converged in   0.02 s, T_max = 1854.0
#  144/ 230 (chi_stoich =  1.4e+01 1/s)  converged in   0.02 s, T_max = 1852.7
#  145/ 230 (chi_stoich =  1.5e+01 1/s)  converged in   0.02 s, T_max = 1851.4
#  146/ 230 (chi_stoich =  1.5e+01 1/s)  converged in   0.02 s, T_max = 1850.2
#  147/ 230 (chi_stoich =  1.5e+01 1/s)  converged in   0.02 s, T_max = 1848.9
#  148/ 230 (chi_stoich =  1.5e+01 1/s)  converged in   0.02 s, T_max = 1847.6
#  149/ 230 (chi_stoich =  1.6e+01 1/s)  converged in   0.02 s, T_max = 1846.4
#  150/ 230 (chi_stoich =  1.6e+01 1/s)  converged in   0.02 s, T_max = 1845.1
#  151/ 230 (chi_stoich =  1.6e+01 1/s)  converged in   0.02 s, T_max = 1843.8
#  152/ 230 (chi_stoich =  1.6e+01 1/s)  converged in   0.02 s, T_max = 1842.6
#  153/ 230 (chi_stoich =  1.6e+01 1/s)  converged in   0.02 s, T_max = 1841.3
#  154/ 230 (chi_stoich =  1.7e+01 1/s)  converged in   0.02 s, T_max = 1840.1
#  155/ 230 (chi_stoich =  1.7e+01 1/s)  converged in   0.02 s, T_max = 1838.8
#  156/ 230 (chi_stoich =  1.7e+01 1/s)  converged in   0.02 s, T_max = 1837.6
#  157/ 230 (chi_stoich =  1.7e+01 1/s)  converged in   0.01 s, T_max = 1836.3
#  158/ 230 (chi_stoich =  1.8e+01 1/s)  converged in   0.02 s, T_max = 1835.1
#  159/ 230 (chi_stoich =  1.8e+01 1/s)  converged in   0.02 s, T_max = 1833.8
#  160/ 230 (chi_stoich =  1.8e+01 1/s)  converged in   0.02 s, T_max = 1832.6
#  161/ 230 (chi_stoich =  1.8e+01 1/s)  converged in   0.02 s, T_max = 1831.3
#  162/ 230 (chi_stoich =  1.8e+01 1/s)  converged in   0.02 s, T_max = 1830.1
#  163/ 230 (chi_stoich =  1.9e+01 1/s)  converged in   0.02 s, T_max = 1828.8
#  164/ 230 (chi_stoich =  1.9e+01 1/s)  converged in   0.02 s, T_max = 1827.6
#  165/ 230 (chi_stoich =  1.9e+01 1/s)  converged in   0.02 s, T_max = 1826.3
#  166/ 230 (chi_stoich =  1.9e+01 1/s)  converged in   0.02 s, T_max = 1825.0
#  167/ 230 (chi_stoich =  2.0e+01 1/s)  converged in   0.02 s, T_max = 1823.8
#  168/ 230 (chi_stoich =  2.0e+01 1/s)  converged in   0.02 s, T_max = 1822.5
#  169/ 230 (chi_stoich =  2.0e+01 1/s)  converged in   0.02 s, T_max = 1821.3
#  170/ 230 (chi_stoich =  2.0e+01 1/s)  converged in   0.02 s, T_max = 1820.0
#  171/ 230 (chi_stoich =  2.0e+01 1/s)  converged in   0.02 s, T_max = 1818.8
#  172/ 230 (chi_stoich =  2.1e+01 1/s)  converged in   0.01 s, T_max = 1817.7
#  173/ 230 (chi_stoich =  2.1e+01 1/s)  converged in   0.02 s, T_max = 1816.5
#  174/ 230 (chi_stoich =  2.1e+01 1/s)  converged in   0.02 s, T_max = 1815.3
#  175/ 230 (chi_stoich =  2.1e+01 1/s)  converged in   0.01 s, T_max = 1814.1
#  176/ 230 (chi_stoich =  2.1e+01 1/s)  converged in   0.01 s, T_max = 1812.9
#  177/ 230 (chi_stoich =  2.2e+01 1/s)  converged in   0.02 s, T_max = 1811.7
#  178/ 230 (chi_stoich =  2.2e+01 1/s)  converged in   0.02 s, T_max = 1810.5
#  179/ 230 (chi_stoich =  2.2e+01 1/s)  converged in   0.02 s, T_max = 1809.3
#  180/ 230 (chi_stoich =  2.2e+01 1/s)  converged in   0.02 s, T_max = 1808.0
#  181/ 230 (chi_stoich =  2.3e+01 1/s)  converged in   0.02 s, T_max = 1806.7
#  182/ 230 (chi_stoich =  2.3e+01 1/s)  converged in   0.03 s, T_max = 1805.4
#  183/ 230 (chi_stoich =  2.3e+01 1/s)  converged in   0.02 s, T_max = 1804.1
#  184/ 230 (chi_stoich =  2.3e+01 1/s)  converged in   0.02 s, T_max = 1802.8
#  185/ 230 (chi_stoich =  2.3e+01 1/s)  converged in   0.02 s, T_max = 1801.5
#  186/ 230 (chi_stoich =  2.4e+01 1/s)  converged in   0.01 s, T_max = 1800.1
#  187/ 230 (chi_stoich =  2.4e+01 1/s)  converged in   0.01 s, T_max = 1798.7
#  188/ 230 (chi_stoich =  2.4e+01 1/s)  converged in   0.02 s, T_max = 1797.3
#  189/ 230 (chi_stoich =  2.4e+01 1/s)  converged in   0.02 s, T_max = 1795.9
#  190/ 230 (chi_stoich =  2.5e+01 1/s)  converged in   0.02 s, T_max = 1794.5
#  191/ 230 (chi_stoich =  2.5e+01 1/s)  converged in   0.01 s, T_max = 1793.0
#  192/ 230 (chi_stoich =  2.5e+01 1/s)  converged in   0.02 s, T_max = 1791.5
#  193/ 230 (chi_stoich =  2.5e+01 1/s)  converged in   0.02 s, T_max = 1790.0
#  194/ 230 (chi_stoich =  2.6e+01 1/s)  converged in   0.02 s, T_max = 1788.5
#  195/ 230 (chi_stoich =  2.6e+01 1/s)  converged in   0.01 s, T_max = 1786.9
#  196/ 230 (chi_stoich =  2.6e+01 1/s)  converged in   0.02 s, T_max = 1785.3
#  197/ 230 (chi_stoich =  2.6e+01 1/s)  converged in   0.02 s, T_max = 1783.7
#  198/ 230 (chi_stoich =  2.7e+01 1/s)  converged in   0.02 s, T_max = 1782.1
#  199/ 230 (chi_stoich =  2.7e+01 1/s)  converged in   0.02 s, T_max = 1780.4
#  200/ 230 (chi_stoich =  2.7e+01 1/s)  converged in   0.02 s, T_max = 1778.7
#  201/ 230 (chi_stoich =  2.7e+01 1/s)  converged in   0.02 s, T_max = 1777.0
#  202/ 230 (chi_stoich =  2.8e+01 1/s)  converged in   0.02 s, T_max = 1775.3
#  203/ 230 (chi_stoich =  2.8e+01 1/s)  converged in   0.02 s, T_max = 1773.5
#  204/ 230 (chi_stoich =  2.8e+01 1/s)  converged in   0.02 s, T_max = 1771.6
#  205/ 230 (chi_stoich =  2.8e+01 1/s)  converged in   0.02 s, T_max = 1769.8
#  206/ 230 (chi_stoich =  2.9e+01 1/s)  converged in   0.02 s, T_max = 1767.9
#  207/ 230 (chi_stoich =  2.9e+01 1/s)  converged in   0.02 s, T_max = 1765.9
#  208/ 230 (chi_stoich =  2.9e+01 1/s)  converged in   0.02 s, T_max = 1763.9
#  209/ 230 (chi_stoich =  3.0e+01 1/s)  converged in   0.02 s, T_max = 1761.9
#  210/ 230 (chi_stoich =  3.0e+01 1/s)  converged in   0.02 s, T_max = 1759.8
#  211/ 230 (chi_stoich =  3.0e+01 1/s)  converged in   0.02 s, T_max = 1757.7
#  212/ 230 (chi_stoich =  3.0e+01 1/s)  converged in   0.02 s, T_max = 1755.5
#  213/ 230 (chi_stoich =  3.1e+01 1/s)  converged in   0.02 s, T_max = 1753.2
#  214/ 230 (chi_stoich =  3.1e+01 1/s)  converged in   0.02 s, T_max = 1750.9
#  215/ 230 (chi_stoich =  3.1e+01 1/s)  converged in   0.02 s, T_max = 1748.6
#  216/ 230 (chi_stoich =  3.2e+01 1/s)  converged in   0.02 s, T_max = 1746.1
#  217/ 230 (chi_stoich =  3.2e+01 1/s)  converged in   0.02 s, T_max = 1743.6
#  218/ 230 (chi_stoich =  3.2e+01 1/s)  converged in   0.02 s, T_max = 1741.0
#  219/ 230 (chi_stoich =  3.3e+01 1/s)  converged in   0.02 s, T_max = 1738.3
#  220/ 230 (chi_stoich =  3.3e+01 1/s)  converged in   0.02 s, T_max = 1735.5
#  221/ 230 (chi_stoich =  3.3e+01 1/s)  converged in   0.02 s, T_max = 1732.5
#  222/ 230 (chi_stoich =  3.4e+01 1/s)  converged in   0.02 s, T_max = 1729.5
#  223/ 230 (chi_stoich =  3.4e+01 1/s)  converged in   0.02 s, T_max = 1726.3
#  224/ 230 (chi_stoich =  3.4e+01 1/s)  converged in   0.02 s, T_max = 1722.9
#  225/ 230 (chi_stoich =  3.5e+01 1/s)  converged in   0.02 s, T_max = 1719.3
#  226/ 230 (chi_stoich =  3.5e+01 1/s)  converged in   0.02 s, T_max = 1715.5
#  227/ 230 (chi_stoich =  3.5e+01 1/s)  converged in   0.02 s, T_max = 1711.4
#  228/ 230 (chi_stoich =  3.6e+01 1/s)  converged in   0.02 s, T_max = 1707.0
#  229/ 230 (chi_stoich =  3.6e+01 1/s)  converged in   0.02 s, T_max = 1702.0
#  230/ 230 (chi_stoich =  3.6e+01 1/s)  converged in   0.02 s, T_max = 1696.5
# ----------------------------------------------------------------------------------
# library built in   6.33 s
# ----------------------------------------------------------------------------------

# %%
print('The last stoichiometric dissipation rate:')
print(l_steady.dissipation_rate_stoich_values[-1])
# Out:
# The last stoichiometric dissipation rate:
# 36.30780547701014

# %% [markdown]
# ***
#
# ## Generate transient flamelet library:

# %%
jump_chi = 1.4

# %%
if generate_transient:
    flamelet_extinction = Flamelet(FlameletSpec(library_slice=l_steady[:, -1], stoich_dissipation_rate=l_steady.dissipation_rate_stoich_values[-1]*jump_chi))
    l_transient = flamelet_extinction.integrate_to_steady(write_log=True)

# %% [markdown]
# ***
#
# ## Generate and save two training data sets (steady & transient):

# %% [markdown]
# ##### Mixture fraction:

# %%
mixture_fraction_steady = l_steady.mixture_fraction_grid.flatten()[:,None]
print(np.shape(mixture_fraction_steady))
# Out:
# (46000, 1)

# %%
if generate_transient:
    mixture_fraction_transient = l_transient.mixture_fraction_grid.flatten()[:,None]
    print(np.shape(mixture_fraction_transient))

# %% [markdown]
# ##### Density (Cantera "`density`"):

# %%
l_steady = analysis.compute_density(chemical_mechanism, l_steady) # kg/m3
density_steady = l_steady['density'].flatten()[:,None]
print(np.shape(density_steady))
# Out:
# (46000, 1)

# %%
if generate_transient:
    l_transient = analysis.compute_density(chemical_mechanism, l_transient) # kg/m3
    density_transient = l_transient['density'].flatten()[:,None]
    print(np.shape(density_transient))

# %% [markdown]
# ##### Dissipation rates:

# %%
chi_steady = l_steady.dissipation_rate_stoich_grid.flatten()[:,None]
print(np.shape(chi_steady))
# Out:
# (46000, 1)

# %%
if generate_transient:
    chi_transient = jump_chi*l_steady.dissipation_rate_stoich_values[-1]*np.ones_like(mixture_fraction_transient)
    print(np.shape(chi_transient))

# %% [markdown]
# ##### Isobaric heat capacity (Cantera "`cp_mass`"):

# %%
l_steady = analysis.compute_isobaric_specific_heat(chemical_mechanism, l_steady) # J/kg/K
isobaric_heat_capacity_steady = l_steady['heat capacity cp'].flatten()[:,None]
print(np.shape(isobaric_heat_capacity_steady))
# Out:
# (46000, 1)

# %%
if generate_transient:
    l_transient = analysis.compute_isobaric_specific_heat(chemical_mechanism, l_transient) # J/kg/K
    isobaric_heat_capacity_transient = l_transient['heat capacity cp'].flatten()[:,None]
    print(np.shape(isobaric_heat_capacity_transient))

# %% [markdown]
# ##### Species mass fractions:

# %%
ct_sa_steady, l_shape_steady = analysis.get_ct_solution_array(chemical_mechanism, l_steady)
mass_fractions_steady = ct_sa_steady.Y # [-]
print(np.shape(mass_fractions_steady))
# Out:
# (46000, 31)

# %%
mole_fractions_steady = ct_sa_steady.X # [-]
print(np.shape(mole_fractions_steady))
# Out:
# (46000, 31)

# %%
np.savetxt(filename_prefix + '-mole-fractions.csv', (mole_fractions_steady), delimiter=',', fmt='%.16e')

# %%
if generate_transient:
    ct_sa_transient, l_shape_transient = analysis.get_ct_solution_array(chemical_mechanism, l_transient)
    mass_fractions_transient = ct_sa_transient.Y # [-]
    print(np.shape(mass_fractions_transient))

# %% [markdown]
# ##### Temperature:

# %%
temperature_steady = ct_sa_steady.T[:,None] # K
print(np.shape(temperature_steady))
# Out:
# (46000, 1)

# %%
if generate_transient:
    temperature_transient = ct_sa_transient.T[:,None] # K
    print(np.shape(temperature_transient))

# %% [markdown]
# ##### Species production rates:

# %%
production_rates_steady = ct_sa_steady.net_production_rates * ct_sa_steady.molecular_weights # kmol/m3-s * kg/kmol = kg/m3-s
production_rates_over_density_steady = np.divide(production_rates_steady, density_steady) # 1/s
print(np.shape(production_rates_steady))
print(np.shape(production_rates_over_density_steady))
# Out:
# (46000, 31)
# (46000, 31)

# %%
if generate_transient:
    production_rates_transient = ct_sa_transient.net_production_rates * ct_sa_transient.molecular_weights # kmol/m3-s * kg/kmol = kg/m3-s
    production_rates_over_density_transient = np.divide(production_rates_transient, density_transient) # 1/s
    print(np.shape(production_rates_transient))
    print(np.shape(production_rates_over_density_transient))

# %% [markdown]
# ##### Species enthalpies:

# %%
species_enthalpies_steady = ct_sa_steady.standard_enthalpies_RT * temperature_steady * gas_constant / ct_sa_steady.molecular_weights # J/kg
print(np.shape(species_enthalpies_steady))
# Out:
# (46000, 31)

# %%
if generate_transient:
    species_enthalpies_transient = ct_sa_transient.standard_enthalpies_RT * temperature_transient * gas_constant / ct_sa_transient.molecular_weights # J/kg
    print(np.shape(species_enthalpies_transient))

# %% [markdown]
# ##### Temperature source term $S_T$:

# %%
temperature_source_steady = - np.sum(production_rates_steady * species_enthalpies_steady, axis=1) / density_steady.ravel() / isobaric_heat_capacity_steady.ravel() # K/s
temperature_source_steady = temperature_source_steady[:,None]
print(np.shape(temperature_source_steady))
# Out:
# (46000, 1)

# %%
if generate_transient:
    temperature_source_transient = - np.sum(production_rates_transient * species_enthalpies_transient, axis=1) / density_transient.ravel() / isobaric_heat_capacity_transient.ravel() # K/s
    temperature_source_transient = temperature_source_transient[:,None]
    print(np.shape(temperature_source_transient))

# %% [markdown]
# ##### Heat release rate:
#
# Other two ways you can compute HRR, both give the same thing:
#
# ```python
# heat_release_rate = - np.sum(ct_sa.net_production_rates * ct_sa.partial_molar_enthalpies, axis=1)
# heat_release_rate = - np.sum(ct_sa.net_rates_of_progress * ct_sa.delta_enthalpy, axis=1)
# ```
#
# see [Cantera tutorial](https://cantera.org/tutorials/python-tutorial.html).

# %%
heat_release_rate_steady = - np.sum(production_rates_steady * species_enthalpies_steady, axis=1)
heat_release_rate_steady = heat_release_rate_steady[:,None]
print(np.shape(heat_release_rate_steady))
# Out:
# (46000, 1)

# %%
if generate_transient:
    heat_release_rate_transient = - np.sum(production_rates_transient * species_enthalpies_transient, axis=1)
    heat_release_rate_transient = heat_release_rate_transient[:,None]
    print(np.shape(heat_release_rate_transient))

# %% [markdown]
# ##### Specific enthalpy:

# %%
specific_enthalpy_steady = ct_sa_steady.enthalpy_mass
specific_enthalpy_steady = specific_enthalpy_steady[:,None]
print(np.shape(specific_enthalpy_steady))
# Out:
# (46000, 1)

# %%
if generate_transient:
    specific_enthalpy_transient = ct_sa_transient.enthalpy_mass
    specific_enthalpy_transient = specific_enthalpy_transient[:,None]
    print(np.shape(specific_enthalpy_transient))

# %% [markdown]
# ##### Entropy:

# %%
entropy_mass_steady = ct_sa_steady.entropy_mass

# %%
entropy_mole_steady = ct_sa_steady.entropy_mole

# %% [markdown]
# ***
#
# ## Save the data sets:

# %% [markdown]
# Prepare state-space and sources of state-space data sets that will be saved:

# %%
if remove_N2:
    STEADY_state_space = np.hstack((temperature_steady, mass_fractions_steady[:,0:-1]))
    STEADY_state_space_sources = np.hstack((temperature_source_steady, production_rates_over_density_steady[:,0:-1]))
    print(np.shape(STEADY_state_space))
    print(np.shape(STEADY_state_space_sources))
else:
    STEADY_state_space = np.hstack((temperature_steady, mass_fractions_steady))
    STEADY_state_space_sources = np.hstack((temperature_source_steady, production_rates_over_density_steady))
    print(np.shape(STEADY_state_space))
    print(np.shape(STEADY_state_space_sources))
# Out:
# (46000, 32)
# (46000, 32)

# %%
if generate_transient:
    if remove_N2:
        TRANSIENT_state_space = np.hstack((temperature_transient, mass_fractions_transient[:,0:-1]))
        TRANSIENT_state_space_sources = np.hstack((temperature_source_transient, production_rates_over_density_transient[:,0:-1]))
        print(np.shape(TRANSIENT_state_space))
        print(np.shape(TRANSIENT_state_space_sources))
    else:
        TRANSIENT_state_space = np.hstack((temperature_transient, mass_fractions_transient))
        TRANSIENT_state_space_sources = np.hstack((temperature_source_transient, production_rates_over_density_transient))
        print(np.shape(TRANSIENT_state_space))
        print(np.shape(TRANSIENT_state_space_sources))

# %%
if remove_N2:
    state_space_names = ['T'] + species_names[0:-1]
    print(state_space_names)
else:
    state_space_names = ['T'] + species_names
    print(state_space_names)
# Out:
# ['T', 'AR', 'N2', 'HE', 'H2', 'H', 'O2', 'O', 'H2O', 'OH', 'H2O2', 'HO2', 'NO', 'N2O', 'NO2', 'HNO', 'HNO2', 'HONO', 'HONO2', 'N2H2', 'H2NN', 'NH2OH', 'HNOH', 'NH3', 'N2H4', 'N', 'NO3', 'NH', 'NNH', 'NH2', 'H2NO', 'N2H3']

# %%
if save_csv:
    
    # Species names:
    np.savetxt(filename_prefix + '-state-space-names.csv', (state_space_names), delimiter=',', fmt="%s")
    if generate_transient: np.savetxt('../data/TRANSIENT-' + filename_prefix + '-state-space-names.csv', (state_space_names), delimiter=',', fmt="%s")
    
    # State-space:
    np.savetxt(filename_prefix + '-state-space.csv', (STEADY_state_space), delimiter=',', fmt='%.16e')
    if generate_transient: np.savetxt('../data/TRANSIENT-' + filename_prefix + '-state-space.csv', (TRANSIENT_state_space), delimiter=',', fmt='%.16e')
    
    # Sources of state-space:
    np.savetxt(filename_prefix + '-state-space-sources.csv', (STEADY_state_space_sources), delimiter=',', fmt='%.16e')
    if generate_transient: np.savetxt('../data/TRANSIENT-' + filename_prefix + '-state-space-sources.csv', (TRANSIENT_state_space_sources), delimiter=',', fmt='%.16e')
    
    # Mixture fraction:
    np.savetxt(filename_prefix + '-mixture-fraction.csv', (mixture_fraction_steady), delimiter=',', fmt='%.16e')
    if generate_transient: np.savetxt('../data/TRANSIENT-' + filename_prefix + '-mixture-fraction.csv', (mixture_fraction_transient), delimiter=',', fmt='%.16e')
    
    # Dissipation rates:
    np.savetxt(filename_prefix + '-dissipation-rates.csv', (chi_steady), delimiter=',', fmt='%.16e')
    if generate_transient: np.savetxt('../data/TRANSIENT-' + filename_prefix + '-dissipation-rates.csv', (chi_transient), delimiter=',', fmt='%.16e')
    
    # Heat release rate:
    np.savetxt(filename_prefix + '-heat-release-rate.csv', (heat_release_rate_steady), delimiter=',', fmt='%.16e')
    if generate_transient: np.savetxt('../data/TRANSIENT-' + filename_prefix + '-heat-release-rate.csv', (heat_release_rate_transient), delimiter=',', fmt='%.16e')
    
    # Specific enthalpy:
    np.savetxt(filename_prefix + '-specific-enthalpy.csv', (specific_enthalpy_steady), delimiter=',', fmt='%.16e')
    if generate_transient: np.savetxt('../data/TRANSIENT-' + filename_prefix + '-specific-enthalpy.csv', (specific_enthalpy_transient), delimiter=',', fmt='%.16e')
    
    print('Data sets saved!')
# Out:
# Data sets saved!

# %% [markdown]
# ***
#
# ## Visualize the data sets

# %% [markdown]
# Concatenate data sets:

# %%
if generate_transient:
    mixture_fractions = np.vstack((mixture_fraction_steady, mixture_fraction_transient))
    state_spaces = np.vstack((STEADY_state_space, TRANSIENT_state_space))
    state_spaces_sources = np.vstack((STEADY_state_space_sources, TRANSIENT_state_space_sources))
    chis = np.vstack((chi_steady, chi_transient))
    hrrs = np.vstack((heat_release_rate_steady, heat_release_rate_transient))
    h = np.vstack((specific_enthalpy_steady, specific_enthalpy_transient))
else:
    mixture_fractions = mixture_fraction_steady
    state_spaces = STEADY_state_space
    state_spaces_sources = STEADY_state_space_sources
    chis = chi_steady
    hrrs = heat_release_rate_steady
    h = specific_enthalpy_steady

# %%
x_label = 'Mixture fraction [-]'
y_label = '$T$ [K]'
figure_size = (8,5)

# %%
plt_both = reduction.plot_2d_manifold(mixture_fractions, state_spaces[:,0], color=entropy_mass_steady, x_label=x_label, y_label=y_label, colorbar_label='$\chi_{st}$ [1/s]', figure_size=figure_size)

# %%
plt_both = reduction.plot_2d_manifold(mixture_fractions, state_spaces[:,0], color=hrrs.ravel(), x_label=x_label, y_label=y_label, colorbar_label='HRR [$W/m^3$]', figure_size=figure_size)

# %%
select_variable = 6
plt_both = reduction.plot_2d_manifold(mixture_fractions, state_spaces[:,0], color=state_spaces[:,select_variable], x_label=x_label, y_label=y_label, colorbar_label='$Y_{' + state_space_names[select_variable] + '}$ [-]', figure_size=figure_size)

# %%
select_source = 6
plt_both = reduction.plot_2d_manifold(mixture_fractions, state_spaces[:,0], color=state_spaces_sources[:,select_source], x_label=x_label, y_label=y_label, colorbar_label='$S_{' + state_space_names[select_source] + '}$ [-]', figure_size=figure_size)

# %%
(_, idx_removed, idx_retained) = preprocess.remove_constant_vars(state_spaces)
pca = reduction.PCA(state_spaces[:,idx_retained], scaling='range', n_components=3)
PCs = pca.transform(state_spaces[:,idx_retained])
PC_sources = pca.transform(state_spaces_sources[:,idx_retained], nocenter=True)

# %%
plt_both = reduction.plot_2d_manifold(PCs[:,0],
                                      PCs[:,1],
                                      color=entropy_mass_steady,
                                      x_label=x_label,
                                      y_label=y_label,
                                      colorbar_label='$S_{Z, 1}$ [1/s]',
                                      color_map='inferno',
                                      figure_size=(5,5))

# %%
import plotly as plty
from plotly import express as px
from plotly import graph_objects as go

def plot_3d(x, y, z, color, cmap='plasma', s=2):

    fig = go.Figure(data=[go.Scatter3d(
        x=x.ravel(),
        y=y.ravel(),
        z=z.ravel(),
        mode='markers',
        marker=dict(
            size=s,
            color=color.ravel(),
            colorscale=cmap,
            opacity=1,
            colorbar=dict(thickness=20)
        )
    )])
    
    fig.update_layout(autosize=False,
                width=1000, height=600,
                margin=dict(l=65, r=50, b=65, t=90),
                scene = dict(
                xaxis_title='x',
                yaxis_title='y',
                zaxis_title='z'))
    
    fig.show()

# %%
plot_3d(PCs[:,0], PCs[:,1], PCs[:,2], PC_sources[:,2], cmap='inferno', s=2)

# %% [markdown]
# ****
